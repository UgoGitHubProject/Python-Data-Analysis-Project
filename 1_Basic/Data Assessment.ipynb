# %%
# Importing Libraries

import ast
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

#Loading Data

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.columns
# Out:
# Index(['job_title_short', 'job_title', 'job_location', 'job_via',
#        'job_schedule_type', 'job_work_from_home', 'search_location',
#        'job_posted_date', 'job_no_degree_mention', 'job_health_insurance',
#        'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg',
#        'company_name', 'job_skills', 'job_type_skills'],
#       dtype='object')

# %%
df['job_skills'][1]
# Out:
# "['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']"

# %%
import numpy as np

np.random.randint(1, 10, 2)
# Out:
# array([9, 5])

# %%
np.random.randint(10)
# Out:
# 0

# %%
data_science_jobs = [
    {'job_title': 'Data Scientist', 'job_skills': "['Python', 'SQL', 'Machine Learning']", 'job_date': '2023-05-12'},
    {'job_title': 'Machine Learning Engineer', 'job_skills': "['TensorFlow', 'PyTorch', 'Deep Learning']", 'job_date': '2023-06-15'},
    {'job_title': 'Data Analyst', 'job_skills': "['Excel', 'SQL', 'Tableau']", 'job_date': '2023-07-08'},
    {'job_title': 'Big Data Engineer', 'job_skills': "['Hadoop', 'Spark', 'Kafka']", 'job_date': '2023-08-22'},
    {'job_title': 'AI Research Scientist', 'job_skills': "['NLP', 'Computer Vision', 'Reinforcement Learning']", 'job_date': '2023-09-10'},
    {'job_title': 'Business Intelligence Analyst', 'job_skills': "['Power BI', 'SQL', 'Data Visualization']", 'job_date': '2023-10-05'},
    {'job_title': 'Computer Vision Engineer', 'job_skills': "['OpenCV', 'Deep Learning', 'Image Processing']", 'job_date': '2023-11-12'},
    {'job_title': 'NLP Engineer', 'job_skills': "['Transformers', 'Hugging Face', 'Text Analytics']", 'job_date': '2023-12-01'},
    {'job_title': 'Data Engineer', 'job_skills': "['SQL', 'ETL', 'Cloud Platforms']", 'job_date': '2024-01-14'},
    {'job_title': 'Quantitative Analyst', 'job_skills': "['R', 'Python', 'Statistical Modeling']", 'job_date': '2024-02-09'},
    {'job_title': 'Data Architect', 'job_skills': "['Database Management', 'SQL', 'Cloud Computing']", 'job_date': '2024-03-21'},
    {'job_title': 'Deep Learning Engineer', 'job_skills': "['Neural Networks', 'PyTorch', 'TensorFlow']", 'job_date': '2024-04-18'},
    {'job_title': 'AI Product Manager', 'job_skills': "['AI Strategy', 'Project Management', 'Business Analytics']", 'job_date': '2024-05-03'},
    {'job_title': 'Risk Analyst', 'job_skills': "['Financial Modeling', 'Statistics', 'Risk Management']", 'job_date': '2024-06-07'},
    {'job_title': 'E-commerce Data Scientist', 'job_skills': "['Python', 'A/B Testing', 'Consumer Analytics']", 'job_date': '2024-07-22'},
    {'job_title': 'Healthcare Data Analyst', 'job_skills': "['SQL', 'Health Informatics', 'Data Cleaning']", 'job_date': '2024-08-30'},
    {'job_title': 'Marketing Data Analyst', 'job_skills': "['Google Analytics', 'Excel', 'SQL']", 'job_date': '2024-09-15'},
    {'job_title': 'Fraud Detection Specialist', 'job_skills': "['Anomaly Detection', 'Python', 'Machine Learning']", 'job_date': '2024-10-28'},
    {'job_title': 'Cloud Data Engineer', 'job_skills': "['AWS', 'GCP', 'Spark']", 'job_date': '2024-11-11'},
    {'job_title': 'AI Ethics Researcher', 'job_skills': "['Ethics in AI', 'Bias Detection', 'Regulatory Compliance']", 'job_date': '2024-12-05'}
]

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 8, 31, 22, 51, 2, 624605)

# %%
data_science_jobs[0]['job_date']
# Out:
# '2023-05-12'

# %%
test_date = data_science_jobs[0]['job_date']

datetime.strptime(test_date, '%Y-%m-%d')
# Out:
# datetime.datetime(2023, 5, 12, 0, 0)

# %%
print(datetime.strptime(test_date, '%Y-%m-%d'))
# Out:
# 2023-05-12 00:00:00

# %%
for job in data_science_jobs:
    job['job_date'] = datetime.strptime(job['job_date'], '%Y-%m-%d')

# %%
data_science_jobs
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': "['Python', 'SQL', 'Machine Learning']",
#   'job_date': datetime.datetime(2023, 5, 12, 0, 0)},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': "['TensorFlow', 'PyTorch', 'Deep Learning']",
#   'job_date': datetime.datetime(2023, 6, 15, 0, 0)},
#  {'job_title': 'Data Analyst',
#   'job_skills': "['Excel', 'SQL', 'Tableau']",
#   'job_date': datetime.datetime(2023, 7, 8, 0, 0)},
#  {'job_title': 'Big Data Engineer',
#   'job_skills': "['Hadoop', 'Spark', 'Kafka']",
#   'job_date': datetime.datetime(2023, 8, 22, 0, 0)},
#  {'job_title': 'AI Research Scientist',
#   'job_skills': "['NLP', 'Computer Vision', 'Reinforcement Learning']",
#   'job_date': datetime.datetime(2023, 9, 10, 0, 0)},
#  {'job_title': 'Business Intelligence Analyst',
#   'job_skills': "['Power BI', 'SQL', 'Data Visualization']",
#   'job_date': datetime.datetime(2023, 10, 5, 0, 0)},
#  {'job_title': 'Computer Vision Engineer',
# ...

# %%
data_science_jobs2 = [
    {'job_title': 'Data Scientist', 'job_skills': "['Python', 'SQL', 'Machine Learning']", 'job_date': '2023-05-12'},
    {'job_title': 'Machine Learning Engineer', 'job_skills': "['TensorFlow', 'PyTorch', 'Deep Learning']", 'job_date': '2023-06-15'},
    {'job_title': 'Data Analyst', 'job_skills': "['Excel', 'SQL', 'Tableau']", 'job_date': '2023-07-08'},
    {'job_title': 'Big Data Engineer', 'job_skills': "['Hadoop', 'Spark', 'Kafka']", 'job_date': '2023-08-22'},
    {'job_title': 'AI Research Scientist', 'job_skills': "['NLP', 'Computer Vision', 'Reinforcement Learning']", 'job_date': '2023-09-10'},
    {'job_title': 'Business Intelligence Analyst', 'job_skills': "['Power BI', 'SQL', 'Data Visualization']", 'job_date': '2023-10-05'},
    {'job_title': 'Computer Vision Engineer', 'job_skills': "['OpenCV', 'Deep Learning', 'Image Processing']", 'job_date': '2023-11-12'},
    {'job_title': 'NLP Engineer', 'job_skills': "['Transformers', 'Hugging Face', 'Text Analytics']", 'job_date': '2023-12-01'},
    {'job_title': 'Data Engineer', 'job_skills': "['SQL', 'ETL', 'Cloud Platforms']", 'job_date': '2024-01-14'},
    {'job_title': 'Quantitative Analyst', 'job_skills': "['R', 'Python', 'Statistical Modeling']", 'job_date': '2024-02-09'},
    {'job_title': 'Data Architect', 'job_skills': "['Database Management', 'SQL', 'Cloud Computing']", 'job_date': '2024-03-21'},
    {'job_title': 'Deep Learning Engineer', 'job_skills': "['Neural Networks', 'PyTorch', 'TensorFlow']", 'job_date': '2024-04-18'},
    {'job_title': 'AI Product Manager', 'job_skills': "['AI Strategy', 'Project Management', 'Business Analytics']", 'job_date': '2024-05-03'},
    {'job_title': 'Risk Analyst', 'job_skills': "['Financial Modeling', 'Statistics', 'Risk Management']", 'job_date': '2024-06-07'},
    {'job_title': 'E-commerce Data Scientist', 'job_skills': "['Python', 'A/B Testing', 'Consumer Analytics']", 'job_date': '2024-07-22'},
    {'job_title': 'Healthcare Data Analyst', 'job_skills': "['SQL', 'Health Informatics', 'Data Cleaning']", 'job_date': '2024-08-30'},
    {'job_title': 'Marketing Data Analyst', 'job_skills': "['Google Analytics', 'Excel', 'SQL']", 'job_date': '2024-09-15'},
    {'job_title': 'Fraud Detection Specialist', 'job_skills': "['Anomaly Detection', 'Python', 'Machine Learning']", 'job_date': '2024-10-28'},
    {'job_title': 'Cloud Data Engineer', 'job_skills': "['AWS', 'GCP', 'Spark']", 'job_date': '2024-11-11'},
    {'job_title': 'AI Ethics Researcher', 'job_skills': "['Ethics in AI', 'Bias Detection', 'Regulatory Compliance']", 'job_date': '2024-12-05'}
]

# %%
from datetime import date

# %%
for job in data_science_jobs2:
    job['job_date'] = date.fromisoformat(job['job_date'])

# %%
data_science_jobs2
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': "['Python', 'SQL', 'Machine Learning']",
#   'job_date': datetime.date(2023, 5, 12)},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': "['TensorFlow', 'PyTorch', 'Deep Learning']",
#   'job_date': datetime.date(2023, 6, 15)},
#  {'job_title': 'Data Analyst',
#   'job_skills': "['Excel', 'SQL', 'Tableau']",
#   'job_date': datetime.date(2023, 7, 8)},
#  {'job_title': 'Big Data Engineer',
#   'job_skills': "['Hadoop', 'Spark', 'Kafka']",
#   'job_date': datetime.date(2023, 8, 22)},
#  {'job_title': 'AI Research Scientist',
#   'job_skills': "['NLP', 'Computer Vision', 'Reinforcement Learning']",
#   'job_date': datetime.date(2023, 9, 10)},
#  {'job_title': 'Business Intelligence Analyst',
#   'job_skills': "['Power BI', 'SQL', 'Data Visualization']",
#   'job_date': datetime.date(2023, 10, 5)},
#  {'job_title': 'Computer Vision Engineer',
#   'job_skills': "['OpenCV', 'Deep Learning', 'Image Processing']",
# ...

# %%
df_data_science_jobs = pd.DataFrame(data_science_jobs2)

# %%
df_data_science_jobs
# Out:
#                         job_title  \
# 0                  Data Scientist
# 1       Machine Learning Engineer
# 2                    Data Analyst
# 3               Big Data Engineer
# 4           AI Research Scientist
# 5   Business Intelligence Analyst
# 6        Computer Vision Engineer
# 7                    NLP Engineer
# 8                   Data Engineer
# 9            Quantitative Analyst
# 10                 Data Architect
# 11         Deep Learning Engineer
# 12             AI Product Manager
# 13                   Risk Analyst
# 14      E-commerce Data Scientist
# 15        Healthcare Data Analyst
# 16         Marketing Data Analyst
# 17     Fraud Detection Specialist
# 18            Cloud Data Engineer
# 19           AI Ethics Researcher
#
#                                            job_skills    job_date
# 0               ['Python', 'SQL', 'Machine Learning']  2023-05-12
# 1          ['TensorFlow', 'PyTorch', 'Deep Learning']  2023-06-15
# ...

# %%
df_data_science_jobs = df_data_science_jobs.set_index('job_title')

df_data_science_jobs
# Out:
#                                                                       job_skills  \
# job_title
# Data Scientist                             ['Python', 'SQL', 'Machine Learning']
# Machine Learning Engineer             ['TensorFlow', 'PyTorch', 'Deep Learning']
# Data Analyst                                         ['Excel', 'SQL', 'Tableau']
# Big Data Engineer                                   ['Hadoop', 'Spark', 'Kafka']
# AI Research Scientist          ['NLP', 'Computer Vision', 'Reinforcement Lear...
# Business Intelligence Analyst          ['Power BI', 'SQL', 'Data Visualization']
# Computer Vision Engineer         ['OpenCV', 'Deep Learning', 'Image Processing']
# NLP Engineer                   ['Transformers', 'Hugging Face', 'Text Analyti...
# Data Engineer                                  ['SQL', 'ETL', 'Cloud Platforms']
# Quantitative Analyst                     ['R', 'Python', 'Statistical Modeling']
# ...

# %%
df_data_science_jobs.iloc[1:10]
# Out:
#                                                                       job_skills  \
# job_title
# Machine Learning Engineer             ['TensorFlow', 'PyTorch', 'Deep Learning']
# Data Analyst                                         ['Excel', 'SQL', 'Tableau']
# Big Data Engineer                                   ['Hadoop', 'Spark', 'Kafka']
# AI Research Scientist          ['NLP', 'Computer Vision', 'Reinforcement Lear...
# Business Intelligence Analyst          ['Power BI', 'SQL', 'Data Visualization']
# Computer Vision Engineer         ['OpenCV', 'Deep Learning', 'Image Processing']
# NLP Engineer                   ['Transformers', 'Hugging Face', 'Text Analyti...
# Data Engineer                                  ['SQL', 'ETL', 'Cloud Platforms']
# Quantitative Analyst                     ['R', 'Python', 'Statistical Modeling']
#
#                                  job_date
# job_title
# Machine Learning Engineer      2023-06-15
# Data Analyst                   2023-07-08
# ...

# %%
df_data_science_jobs[['job_skills', 'job_date']].iloc[0 : 2]
# Out:
#                                                            job_skills  \
# job_title
# Data Scientist                  ['Python', 'SQL', 'Machine Learning']
# Machine Learning Engineer  ['TensorFlow', 'PyTorch', 'Deep Learning']
#
#                              job_date
# job_title
# Data Scientist             2023-05-12
# Machine Learning Engineer  2023-06-15

# %%
df_copy = df.copy()

df_copy1 = df.copy()

# %%
df_copy = df_copy[df_copy['salary_year_avg'].notna()]

df_copy
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# ...                ...                                                ...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location          job_via  \
# ...

# %%
df_copy1.dropna(subset = ['salary_year_avg'], inplace = True)

df_copy1
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# ...                ...                                                ...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location          job_via  \
# ...

# %%
df_copy.count()
# Out:
# job_title_short          22003
# job_title                22003
# job_location             21723
# job_via                  22003
# job_schedule_type        21987
# job_work_from_home       22003
# search_location          22003
# job_posted_date          22003
# job_no_degree_mention    22003
# job_health_insurance     22003
# job_country              22003
# salary_rate              22003
# salary_year_avg          22003
# salary_hour_avg              0
# company_name             22003
# job_skills               20170
# job_type_skills          20170
# dtype: int64

# %%
df_copy['job_title_short'].count()
# Out:
# 22003

# %%
df_copy1.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000              0.0
# mean     123286.274072              NaN
# std       48312.449482              NaN
# min       15000.000000              NaN
# 25%       90000.000000              NaN
# 50%      115000.000000              NaN
# 75%      150000.000000              NaN
# max      960000.000000              NaN

# %%
df_copy1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22003 entries, 28 to 785692
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  salary_hour_avg        0 non-null      float64
# ...

# %%
df_copy1 = df_copy1.drop(labels = 'salary_hour_avg', axis = 1)

df_copy1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22003 entries, 28 to 785692
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  company_name           22003 non-null  object
# ...

# %%
min_salary_index = df['salary_year_avg'].idxmin()

# %%
df.iloc[min_salary_index]
# Out:
# job_title_short                                              Data Engineer
# job_title                                           Data Engineer - Hadoop
# job_location                                                        Brazil
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                     Brazil
# job_posted_date                                        2023-12-09 10:05:30
# job_no_degree_mention                                                 True
# job_health_insurance                                                 False
# job_country                                                         Brazil
# salary_rate                                                           year
# ...

# %%
df['job_title_short'].value_counts()
# Out:
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: job_title_short, dtype: int64

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 6E2C-B299
#
#  Directory of c:\Users\USER\Desktop\PERSONAL FOLDER\PYTHON FOR DATA ANALYSIS LUKEBAROUSSE\Python Data Analysis Project\1_Basic
#
# 08/26/2025  02:57 PM    <DIR>          .
# 08/26/2025  02:57 PM    <DIR>          ..
# 08/28/2025  09:12 PM           181,549 Data Assessment.ipynb
# 08/26/2025  06:53 PM           880,867 SIMPLE_DATA_CLEANING.ipynb
#                2 File(s)      1,062,416 bytes
#                2 Dir(s)  47,836,561,408 bytes free

# %%
df_copy1.groupby(['job_title_short', 'job_country'])['salary_year_avg'].min()
# Out:
# job_title_short    job_country
# Business Analyst   Argentina               63000.0
#                    Australia               63000.0
#                    Bangladesh              16500.0
#                    Belgium                 72900.0
#                    Bulgaria                63000.0
#                                             ...
# Software Engineer  Ukraine                 54000.0
#                    United Arab Emirates    79200.0
#                    United Kingdom          89100.0
#                    United States           48982.0
#                    Vietnam                 28000.0
# Name: salary_year_avg, Length: 598, dtype: float64

# %%
df_copy1.groupby(['job_country', 'job_title_short'])['salary_year_avg'].min()
# Out:
# job_country  job_title_short
# Albania      Data Analyst              43200.0
#              Data Scientist            69962.5
#              Senior Data Scientist    157500.0
# Algeria      Data Analyst              44100.0
#              Data Engineer             45000.0
#                                         ...
# Vietnam      Senior Data Scientist     79200.0
#              Software Engineer         28000.0
# Zambia       Data Scientist            90670.0
# Zimbabwe     Data Analyst              63000.0
#              Data Scientist            47500.0
# Name: salary_year_avg, Length: 598, dtype: float64

# %%
(df_copy1['job_country'] == 'Nigeria').any()
# Out:
# True

# %%
df.groupby(['job_title_short', 'job_country'])['salary_year_avg', 'salary_hour_avg'].median()
# Out:
# <ipython-input-38-ebb00726d124>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['job_title_short', 'job_country'])['salary_year_avg', 'salary_hour_avg'].median()
#                                salary_year_avg  salary_hour_avg
# job_title_short   job_country
# Business Analyst  Afghanistan              NaN              NaN
#                   Albania                  NaN              NaN
#                   Algeria                  NaN              NaN
#                   Angola                   NaN              NaN
#                   Argentina            71100.0              NaN
# ...                                        ...              ...
# Software Engineer Venezuela                NaN              NaN
#                   Vietnam              53600.0              NaN
#                   Yemen                    NaN              NaN
# ...

# %%
df.groupby(['job_title_short', 'job_country'])['salary_year_avg', 'salary_hour_avg'].mean()
# Out:
# <ipython-input-39-a0683ed37eab>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['job_title_short', 'job_country'])['salary_year_avg', 'salary_hour_avg'].mean()
#                                salary_year_avg  salary_hour_avg
# job_title_short   job_country
# Business Analyst  Afghanistan              NaN              NaN
#                   Albania                  NaN              NaN
#                   Algeria                  NaN              NaN
#                   Angola                   NaN              NaN
#                   Argentina            71100.0              NaN
# ...                                        ...              ...
# Software Engineer Venezuela                NaN              NaN
#                   Vietnam              53600.0              NaN
#                   Yemen                    NaN              NaN
# ...

# %%
df.groupby('job_title_short')['salary_year_avg'].agg(['min', 'max', 'median'])
# Out:
#                                min       max    median
# job_title_short
# Business Analyst           16500.0  387460.0   85000.0
# Cloud Engineer             42000.0  280000.0   90000.0
# Data Analyst               25000.0  650000.0   90000.0
# Data Engineer              15000.0  525000.0  125000.0
# Data Scientist             27000.0  960000.0  127500.0
# Machine Learning Engineer  30000.0  325000.0  106415.0
# Senior Data Analyst        30000.0  425000.0  111175.0
# Senior Data Engineer       35000.0  425000.0  147500.0
# Senior Data Scientist      45000.0  890000.0  155500.0
# Software Engineer          28000.0  375000.0   99150.0

# %%
df['job_country'].value_counts().head(20)
# Out:
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Singapore          23696
# Sudan              21781
# Netherlands        20631
# Italy              17013
# Canada             16029
# Mexico             15139
# Poland             14793
# Portugal           14508
# Australia          12955
# South Africa       12414
# Belgium            12078
# Philippines        11786
# Ireland            11162
# Switzerland         9924
# Name: job_country, dtype: int64

# %%
us_jobs = df[df['job_country'] == 'United States']

us_jobs
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# ...

# %%
us_jobs = us_jobs[us_jobs['salary_year_avg'].notna()]

us_jobs
# Out:
#        job_title_short                                          job_title  \
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# 116     Data Scientist                                     Data Scientist
# 146      Data Engineer  Data Engineer Graduate (Real Time Communicatio...
# ...                ...                                                ...
# 785563  Data Scientist  Data Scientist I/II (Model Risk Management & M...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#              job_location                                    job_via  \
# ...

# %%
us_jobs.groupby('job_title_short')[['salary_year_avg']].agg('median')
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   90000.0
# Cloud Engineer                    116100.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    130000.0
# Machine Learning Engineer         150000.0
# Senior Data Analyst               110000.0
# Senior Data Engineer              150000.0
# Senior Data Scientist             155000.0
# Software Engineer                 130000.0

# %%
us_jobs.groupby('job_title_short')[['salary_year_avg']].agg('count')
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                       431
# Cloud Engineer                          20
# Data Analyst                          4350
# Data Engineer                         2915
# Data Scientist                        4553
# Machine Learning Engineer              128
# Senior Data Analyst                    913
# Senior Data Engineer                  1058
# Senior Data Scientist                 1241
# Software Engineer                      157

# %%
us_jobs.groupby('job_title_short')[['salary_year_avg']].agg('size')
# Out:
# job_title_short
# Business Analyst              431
# Cloud Engineer                 20
# Data Analyst                 4350
# Data Engineer                2915
# Data Scientist               4553
# Machine Learning Engineer     128
# Senior Data Analyst           913
# Senior Data Engineer         1058
# Senior Data Scientist        1241
# Software Engineer             157
# dtype: int64

# %%
us_jobs.groupby('job_title_short')[['salary_year_avg']].agg(['median', 'min', 'max', 'count', 'size'])
# Out:
#                           salary_year_avg
#                                    median      min       max count  size
# job_title_short
# Business Analyst                  90000.0  35000.0  387460.0   431   431
# Cloud Engineer                   116100.0  42000.0  221844.0    20    20
# Data Analyst                      90000.0  25000.0  375000.0  4350  4350
# Data Engineer                    125000.0  23496.0  525000.0  2915  2915
# Data Scientist                   130000.0  30000.0  960000.0  4553  4553
# Machine Learning Engineer        150000.0  44408.5  315000.0   128   128
# Senior Data Analyst              110000.0  35360.0  425000.0   913   913
# Senior Data Engineer             150000.0  45000.0  375000.0  1058  1058
# Senior Data Scientist            155000.0  55000.0  475000.0  1241  1241
# Software Engineer                130000.0  48982.0  375000.0   157   157

# %%
us_jobs.groupby('job_title_short')['salary_year_avg'].agg(['median', 'min', 'max', 'count', 'size']).sort_values(
                                                                'median')
# Out:
#                              median      min       max  count  size
# job_title_short
# Business Analyst            90000.0  35000.0  387460.0    431   431
# Data Analyst                90000.0  25000.0  375000.0   4350  4350
# Senior Data Analyst        110000.0  35360.0  425000.0    913   913
# Cloud Engineer             116100.0  42000.0  221844.0     20    20
# Data Engineer              125000.0  23496.0  525000.0   2915  2915
# Data Scientist             130000.0  30000.0  960000.0   4553  4553
# Software Engineer          130000.0  48982.0  375000.0    157   157
# Machine Learning Engineer  150000.0  44408.5  315000.0    128   128
# Senior Data Engineer       150000.0  45000.0  375000.0   1058  1058
# Senior Data Scientist      155000.0  55000.0  475000.0   1241  1241

# %%
us_jobs.groupby('job_title_short')['salary_year_avg'].agg(['median', 'min', 'max', 'count', 'size'])
# Out:
#                              median      min       max  count  size
# job_title_short
# Business Analyst            90000.0  35000.0  387460.0    431   431
# Cloud Engineer             116100.0  42000.0  221844.0     20    20
# Data Analyst                90000.0  25000.0  375000.0   4350  4350
# Data Engineer              125000.0  23496.0  525000.0   2915  2915
# Data Scientist             130000.0  30000.0  960000.0   4553  4553
# Machine Learning Engineer  150000.0  44408.5  315000.0    128   128
# Senior Data Analyst        110000.0  35360.0  425000.0    913   913
# Senior Data Engineer       150000.0  45000.0  375000.0   1058  1058
# Senior Data Scientist      155000.0  55000.0  475000.0   1241  1241
# Software Engineer          130000.0  48982.0  375000.0    157   157

# %%
us_jobs.groupby(['job_title_short', 'job_country'])['salary_year_avg'].min().dropna()
# Out:
# job_title_short            job_country
# Business Analyst           United States    35000.0
# Cloud Engineer             United States    42000.0
# Data Analyst               United States    25000.0
# Data Engineer              United States    23496.0
# Data Scientist             United States    30000.0
# Machine Learning Engineer  United States    44408.5
# Senior Data Analyst        United States    35360.0
# Senior Data Engineer       United States    45000.0
# Senior Data Scientist      United States    55000.0
# Software Engineer          United States    48982.0
# Name: salary_year_avg, dtype: float64

# %%
us_jobs.groupby(['job_title_short', 'job_country']).agg({'salary_year_avg' : ['max', 'min']}).dropna()
# Out:
#                                         salary_year_avg
#                                                     max      min
# job_title_short           job_country
# Business Analyst          United States        387460.0  35000.0
# Cloud Engineer            United States        221844.0  42000.0
# Data Analyst              United States        375000.0  25000.0
# Data Engineer             United States        525000.0  23496.0
# Data Scientist            United States        960000.0  30000.0
# Machine Learning Engineer United States        315000.0  44408.5
# Senior Data Analyst       United States        425000.0  35360.0
# Senior Data Engineer      United States        375000.0  45000.0
# Senior Data Scientist     United States        475000.0  55000.0
# Software Engineer         United States        375000.0  48982.0

# %%
us_jobs.groupby(['job_title_short', 'job_country']).agg({'salary_year_avg' : ['min']}).dropna()
# Out:
#                                         salary_year_avg
#                                                     min
# job_title_short           job_country
# Business Analyst          United States         35000.0
# Cloud Engineer            United States         42000.0
# Data Analyst              United States         25000.0
# Data Engineer             United States         23496.0
# Data Scientist            United States         30000.0
# Machine Learning Engineer United States         44408.5
# Senior Data Analyst       United States         35360.0
# Senior Data Engineer      United States         45000.0
# Senior Data Scientist     United States         55000.0
# Software Engineer         United States         48982.0

# %%
us_jobs.groupby('job_title_short').agg({'salary_year_avg' : ['max']}).dropna()
# Out:
#                           salary_year_avg
#                                       max
# job_title_short
# Business Analyst                 387460.0
# Cloud Engineer                   221844.0
# Data Analyst                     375000.0
# Data Engineer                    525000.0
# Data Scientist                   960000.0
# Machine Learning Engineer        315000.0
# Senior Data Analyst              425000.0
# Senior Data Engineer             375000.0
# Senior Data Scientist            475000.0
# Software Engineer                375000.0

# %%
us_jobs.groupby('job_title_short')['salary_year_avg'].agg('max').dropna()
# Out:
# job_title_short
# Business Analyst             387460.0
# Cloud Engineer               221844.0
# Data Analyst                 375000.0
# Data Engineer                525000.0
# Data Scientist               960000.0
# Machine Learning Engineer    315000.0
# Senior Data Analyst          425000.0
# Senior Data Engineer         375000.0
# Senior Data Scientist        475000.0
# Software Engineer            375000.0
# Name: salary_year_avg, dtype: float64

# %%
name = 'Ugochukwu'

name[::-1]
# Out:
# 'uwkuhcogU'

# %%
name[:-1:]
# Out:
# 'Ugochukw'

# %%
name[-1::]
# Out:
# 'u'
