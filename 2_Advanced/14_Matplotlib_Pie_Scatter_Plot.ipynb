# %%
# Import the Libraries

import ast
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

# Load the Dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x : ast.literal_eval(x) if pd.notna(x) else x)

# %%
wfh = df['job_work_from_home'].value_counts()

wfh.plot(kind = 'pie', startangle = 90)
plt.title("Work from Home Status")
plt.ylabel(" ")
plt.show()

# %%
jts = df['job_title_short'].value_counts()

jts.plot(kind = 'pie', startangle = 180)
plt.title("Tob Titles from Luke's Dataset")
plt.ylabel(" ")
plt.show()

# %%
wfh = df['job_work_from_home'].value_counts()

wfh.plot(kind = 'pie', startangle = 90, autopct = "%1.2f%%")
plt.title("Work from Home Status")
plt.ylabel(" ")
plt.show()

# %%
fig, ax = plt.subplots(1, 3)

dict_column = { 'job_work_from_home' : 'Work from Home',
                'job_no_degree_mention' : 'Job Degree Required' ,
                'job_health_insurance' : 'Health Insurance Offered'
}

for i, (column, title) in enumerate(dict_column.items()) :
    ax[i].pie(df[column].value_counts(), startangle = 90, autopct = '%1.1f%%')
    ax[i].set_title(title)

fig.tight_layout()

plt.show()

# %%
jts = df['job_title_short'].value_counts()

jts.plot(kind = 'pie', startangle = 180, autopct = '%1.1f%%')
plt.title("Tob Titles from Luke's Dataset")
plt.ylabel(" ")
plt.show()

# %%
wfh = df['job_work_from_home'].value_counts()

wfh
# Out:
# job_work_from_home
# False    716189
# True      69552
# Name: count, dtype: int64

# %%
jts = df['job_title_short'].value_counts()

jts
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(1, 3)

dict_column = { 'job_work_from_home' : 'Work from Home',
                'job_no_degree_mention' : 'Job Degree Required' ,
                'job_health_insurance' : 'Health Insurance Offered'
}

for i, (column, title) in enumerate(dict_column.items()) :
    df[column].value_counts().plot(kind = 'pie', startangle = 90, autopct = '%1.1f%%', ax = ax[i])
    ax[i].set_title(title)
    ax[i].set_ylabel(" ")

fig.tight_layout()

plt.show()
