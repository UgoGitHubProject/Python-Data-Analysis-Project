# %%
# Import the Libraries

import ast
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

# Load the Dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x : ast.literal_eval(x) if pd.notna(x) else x)

# Filter for Data Analyst
df_DA = df[df['job_title_short'] == 'Data Analyst'].copy()

# %%
# Create a new column for month number

df_DA['job_posted_month_no'] = df_DA['job_posted_date'].dt.month

# %%
# Explode the job skills column and pivot
# Pivotting is done to see the trend of job skills over time (month)

df_DA_explode = df_DA.explode('job_skills')

df_DA_pivot = df_DA_explode.pivot_table(index = 'job_posted_month_no', columns = 'job_skills', aggfunc = 'size',
                                        fill_value = 0)

df_DA_pivot
# Out:
# job_skills           airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month_no
# 1                        197        17      551       63           2       20
# 2                        169         2      448       49           0       14
# 3                        181         4      442       34           0       23
# 4                        155         4      413       22           0       11
# 5                        128         8      310       30           0       19
# 6                        164        14      393       29           0       14
# 7                        207         4      366       15           0        8
# 8                        197         3      413       21           0       12
# 9                        118         4      317       21           0       14
# 10                       173        11      350       40           0       19
# 11                       169         7      293       24           0       19
# ...

# %%
# Sort the skills by count

df_DA_pivot.loc['Total'] = df_DA_pivot.sum()

df_DA_pivot.loc['Total'].sort_values(ascending = False).index

df_DA_pivot = df_DA_pivot[df_DA_pivot.loc['Total'].sort_values(ascending = False).index]

df_DA_pivot = df_DA_pivot.drop('Total')

df_DA_pivot
# Out:
# job_skills             sql  excel  python  tableau  power bi     r   sas  \
# job_posted_month_no
# 1                    11336   8170    6606     5596      4285  3607  3830
# 2                     7947   5772    4751     3936      3307  2576  2634
# 3                     7868   5675    4741     4051      3176  2650  2554
# 4                     7553   5496    4557     3776      3106  2399  2598
# 5                     6617   4773    4070     3245      2695  2093  1940
# 6                     7584   5724    4707     3812      3275  2442  2174
# 7                     7687   5513    4831     3928      3350  2444  2118
# 8                     8823   6482    5576     4533      3859  2975  2560
# 9                     6829   4886    4229     3446      3118  2146  1880
# 10                    7474   5217    4693     3709      3340  2380  2114
# 11                    6652   4776    4233     3284      3012  2159  1738
# 12                    6058   4376    4196     3139      2857  2125  1858
# ...

# %%
# Use the month names for plotting

df_DA_pivot = df_DA_pivot.reset_index()

df_DA_pivot['job_posted_month'] = df_DA_pivot['job_posted_month_no'].apply(lambda x : pd.to_datetime(x, format = '%m').
                                                                            strftime('%b'))

df_DA_pivot = df_DA_pivot.set_index('job_posted_month')

df_DA_pivot = df_DA_pivot.drop(columns = 'job_posted_month_no')

# %%
df_DA_pivot
# Out:
# job_skills          sql  excel  python  tableau  power bi     r   sas  \
# job_posted_month
# Jan               11336   8170    6606     5596      4285  3607  3830
# Feb                7947   5772    4751     3936      3307  2576  2634
# Mar                7868   5675    4741     4051      3176  2650  2554
# Apr                7553   5496    4557     3776      3106  2399  2598
# May                6617   4773    4070     3245      2695  2093  1940
# Jun                7584   5724    4707     3812      3275  2442  2174
# Jul                7687   5513    4831     3928      3350  2444  2118
# Aug                8823   6482    5576     4533      3859  2975  2560
# Sep                6829   4886    4229     3446      3118  2146  1880
# Oct                7474   5217    4693     3709      3340  2380  2114
# Nov                6652   4776    4233     3284      3012  2159  1738
# Dec                6058   4376    4196     3139      2857  2125  1858
#
# ...

# %%
# Get the top 5 skills and make a plot

df_DA_pivot.iloc[:, :5].plot(kind = 'line')
plt.title('Tof 5 Skills for Data Analysts per Month')
plt.ylabel('Count')
plt.xlabel('')
plt.show()

# %%
# Get the top 5 skills, make a plot and configure certain plot parts

df_DA_pivot.iloc[:, :5].plot(
    kind = 'line',
    linewidth = 4,
    linestyle = ':' ,
    colormap = 'viridis' ,
    markersize = 5 ,
    marker = 'o' ,
    figsize = (10, 5)
)
plt.title('Tof 5 Skills for Data Analysts per Month')
plt.ylabel('Count')
plt.xlabel('')
plt.show()

# %%
df_USA = df[df['job_country'] == "United States"]

df_USA
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# ...

# %%
df_USA.value_counts('job_title_short').index
# Out:
# Index(['Data Analyst', 'Data Scientist', 'Data Engineer',
#        'Senior Data Scientist', 'Senior Data Analyst', 'Senior Data Engineer',
#        'Business Analyst', 'Software Engineer', 'Machine Learning Engineer',
#        'Cloud Engineer'],
#       dtype='object', name='job_title_short')

# %%
top3 = df_USA.value_counts('job_title_short').head(3).index

top3
# Out:
# Index(['Data Analyst', 'Data Scientist', 'Data Engineer'], dtype='object', name='job_title_short')

# %%
type(top3)
# Out:
# pandas.core.indexes.base.Index

# %%
df_USA['job_posted_month'] = df_USA['job_posted_date'].dt.strftime('%B').copy()

df_USA
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_15500\2592622522.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_USA['job_posted_month'] = df_USA['job_posted_date'].dt.strftime('%B').copy()
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# ...

# %%
df_USA_pivot = df_USA.pivot_table(index = 'job_posted_month', columns = 'job_title_short', aggfunc = 'size')

df_USA_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# April                          565              40          6049
# August                         903              39          6634
# December                       648              40          3979
# February                       447              24          6124
# January                        527              36          8494
# July                           581              39          5201
# June                           446              32          5683
# March                          438              19          6218
# May                            279              20          4993
# November                       719              36          4531
# October                        932              48          5271
# September                      897              50          4639
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df_USA_pivot[top3]
# Out:
# job_title_short   Data Analyst  Data Scientist  Data Engineer
# job_posted_month
# April                     6049            4867           2801
# August                    6634            6318           3269
# December                  3979            3472           2641
# February                  6124            4956           3060
# January                   8494            6915           2655
# July                      5201            4876           2570
# June                      5683            4645           2893
# March                     6218            4779           3183
# May                       4993            4377           2976
# November                  4531            4175           2793
# October                   5271            4882           3015
# September                 4639            4568           3224

# %% [markdown]
# # Customize the Scatter Plot

# %%
# Make another copy of the dataset filtered for Data Analyst

df_DA_copy = df[df['job_title_short'] == 'Data Analyst'].copy()

df_explode = df_DA_copy.explode('job_skills')

# %%
# Calculate the median salary and the count of job postings per skill
# For each skill return the count of the skill and the median salary
# for that skill.

skill_stats = df_explode.groupby('job_skills').agg(skill_count = ('job_skills', 'count'),
                                                   median_salary = ('salary_year_avg', 'median'))

skill_stats
# Out:
#             skill_count  median_salary
# job_skills
# airflow            2002       111175.0
# airtable             88        90000.0
# alteryx            4570       105000.0
# angular             376       109101.0
# angular.js            2            NaN
# ...                 ...            ...
# wrike                39        75000.0
# wsl                  16            NaN
# xamarin               2            NaN
# yarn                 76        99150.0
# zoom                465        81167.0
#
# [235 rows x 2 columns]

# %%
# Limit the number of top skills

skill_count = 20

skill_stats = skill_stats.sort_values(by = 'skill_count', ascending = False).head(skill_count)

skill_stats
# Out:
#             skill_count  median_salary
# job_skills
# sql               92428   92500.000000
# excel             66860   84479.000000
# python            57190   98500.000000
# tableau           46455   95000.000000
# power bi          39380   90000.000000
# r                 29996   92527.500000
# sas               27998   90000.000000
# powerpoint        13822   85000.000000
# word              13562   80000.000000
# sap               11280   90000.000000
# azure             10913  100000.000000
# oracle            10387   95000.000000
# aws                9047  100500.000000
# sql server         8288   92150.000000
# go                 7905   90000.000000
# flow               7259   94450.000000
# vba                6841   90000.000000
# looker             6259  104000.000000
# snowflake          6178  110240.109375
# qlik               5681  100000.000000

# %%
skill_stats.plot(kind = 'scatter', x = 'skill_count', y = 'median_salary')
plt.xlabel("Count of Job Posting")
plt.ylabel("Median Yearly Salary ($USD)")
plt.title(f"Salary vs. Count of Job Postings for top {skill_count} Skills")

for i, txt in enumerate(skill_stats.index):
    plt.text(skill_stats['skill_count'].iloc[i], skill_stats['median_salary'].iloc[i], txt)

plt.tight_layout()
plt.show()

# %%
from adjustText import adjust_text

skill_stats.plot(kind = 'scatter', x = 'skill_count', y = 'median_salary')

texts = []

for i, txt in enumerate(skill_stats.index):
    texts.append(plt.text(skill_stats['skill_count'].iloc[i], skill_stats['median_salary'].iloc[i], txt))

adjust_text(texts, arrowprops = dict(arrowstyle = "->", color = 'grey', lw = 2))

plt.xlabel("Count of Job Posting")
plt.ylabel("Median Yearly Salary ($USD)")
plt.title(f"Salary vs. Count of Job Postings for top {skill_count} Skills")    

plt.tight_layout()
plt.show()

# %%
skill_stats

skill_stats.plot(kind = 'scatter', x = 'skill_count', y = 'median_salary')

texts = []

for i, txt in enumerate(skill_stats.index):
    texts.append(plt.text(skill_stats['skill_count'].iloc[i], skill_stats['median_salary'].iloc[i], txt))

adjust_text(texts, arrowprops = dict(arrowstyle = "->", color = 'grey', lw = 2))

ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos : f'${int(y/1000)}K'))

plt.xlabel("Count of Job Posting")
plt.ylabel("Median Yearly Salary ($USD)")
plt.title(f"Salary vs. Count of Job Postings for top {skill_count} Skills")    

plt.tight_layout()
plt.show()
