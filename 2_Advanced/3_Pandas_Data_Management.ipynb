# %%
# Import the libraries

import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

# Load the Dataset from HuggingFace
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(5)
# Out:
#        job_title_short               job_title                 job_location  \
# 522761    Data Analyst    Data Analyst (m/w/d)            Bayreuth, Germany
# 643164    Data Analyst            Data Analyst             Lisbon, Portugal
# 276960    Data Analyst            Data Analyst                     Anywhere
# 778451    Data Analyst        Auxiliar de Data     Bogotá, Bogota, Colombia
# 627085   Data Engineer  Data Engineer - EB4603  Hyderabad, Telangana, India
#
#                        job_via job_schedule_type  job_work_from_home  \
# 522761                via XING         Full-time               False
# 643164      via BeBee Portugal         Full-time               False
# 276960  via Motion Recruitment         Full-time                True
# 778451         via Trabajo.org         Full-time               False
# 627085            via LinkedIn         Full-time               False
#
#              search_location     job_posted_date  job_no_degree_mention  \
# 522761               Germany 2023-06-12 11:38:57                   True
# 643164              Portugal 2023-06-23 13:18:16                   True
# 276960  Texas, United States 2023-07-24 07:01:42                   True
# 778451              Colombia 2023-01-18 05:43:14                   True
# 627085                 India 2023-05-09 12:33:03                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 522761                 False        Germany        None              NaN
# 643164                 False       Portugal        None              NaN
# 276960                  True  United States        year          85000.0
# 778451                 False       Colombia        None              NaN
# 627085                 False          India        None              NaN
#
#         salary_hour_avg                           company_name  \
# 522761              NaN  Excellence AG - GreenTech Engineering
# 643164              NaN                                Olisipo
# 276960              NaN                     Motion Recruitment
# 778451              NaN                           Grupo Sancho
# 627085              NaN                                  Nisum
#
#                                                job_skills  \
# 522761                                            ['sap']
# 643164  ['sql', 'sas', 'sas', 'sql server', 'excel', '...
# 276960    ['sql', 'sql server', 'mysql', 'azure', 'jira']
# 778451                                          ['excel']
# 627085                 ['java', 'aws', 'splunk', 'excel']
#
#                                           job_type_skills
# 522761                         {'analyst_tools': ['sap']}
# 643164  {'analyst_tools': ['sas', 'excel', 'power bi']...
# 276960  {'async': ['jira'], 'cloud': ['azure'], 'datab...
# 778451                       {'analyst_tools': ['excel']}
# 627085  {'analyst_tools': ['splunk', 'excel'], 'cloud'...

# %%
df.sample(5, random_state = 10)
# Out:
#             job_title_short            job_title      job_location  \
# 189968        Data Engineer        Data Engineer        London, UK
# 559367        Data Engineer  (Mid) Data Engineer             Spain
# 233787  Senior Data Analyst  Senior Data Analyst             Chile
# 776749        Data Engineer        Data Engineer  Kathmandu, Nepal
# 466836         Data Analyst  Junior Data Analyst  Waregem, Belgium
#
#                    job_via job_schedule_type  job_work_from_home  \
# 189968       via WREG Jobs         Full-time               False
# 559367           via BeBee         Full-time               False
# 233787     via BeBee Chile         Full-time               False
# 776749  via LinkedIn Nepal         Full-time               False
# 466836            via VDAB         Full-time               False
#
#        search_location     job_posted_date  job_no_degree_mention  \
# 189968  United Kingdom 2023-08-18 15:17:58                   True
# 559367           Spain 2023-09-28 04:33:10                   True
# 233787           Chile 2023-06-16 07:52:25                   True
# 776749           Nepal 2023-01-23 05:57:15                  False
# 466836         Belgium 2023-09-11 14:25:16                   True
#
#         job_health_insurance     job_country salary_rate  salary_year_avg  \
# 189968                 False  United Kingdom        None              NaN
# 559367                 False           Spain        None              NaN
# 233787                 False           Chile        None              NaN
# 776749                 False           Nepal        None              NaN
# 466836                 False         Belgium        None              NaN
#
#         salary_hour_avg                   company_name  \
# 189968              NaN        SC4 Recruitment Limited
# 559367              NaN                      PIA Media
# 233787              NaN  Business Agility – Portfolios
# 776749              NaN             Reputed IT Company
# 466836              NaN                           HAYS
#
#                                                job_skills  \
# 189968                                        ['airflow']
# 559367  ['sql', 'python', 'bigquery', 'airflow', 'linu...
# 233787  ['sql', 'r', 'python', 'elasticsearch', 'azure...
# 776749  ['sql', 't-sql', 'c#', 'python', 'vba', 'sql s...
# 466836                                       ['power bi']
#
#                                           job_type_skills
# 189968                         {'libraries': ['airflow']}
# 559367  {'cloud': ['bigquery'], 'libraries': ['airflow...
# 233787  {'cloud': ['azure'], 'databases': ['elasticsea...
# 776749  {'analyst_tools': ['ssrs'], 'databases': ['sql...
# 466836                    {'analyst_tools': ['power bi']}

# %%
df.sample(5, random_state = 42)
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
#
#                    job_location          job_via job_schedule_type  \
# 502901              St Paul, MN        via BeBee         Full-time
# 406337               London, UK     via LinkedIn         Full-time
# 659951  Newcastle upon Tyne, UK       via Indeed         Full-time
# 541593                    Malta  via Trabajo.org         Full-time
# 425158   Amsterdam, Netherlands   via NBC4i Jobs         Full-time
#
#         job_work_from_home         search_location     job_posted_date  \
# 502901               False  Florida, United States 2023-12-17 11:09:06
# 406337               False          United Kingdom 2023-10-06 16:09:56
# 659951               False          United Kingdom 2023-09-06 10:11:25
# 541593               False                   Malta 2023-02-14 21:14:18
# 425158               False             Netherlands 2023-06-19 16:34:30
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 502901                  False                 False   United States
# 406337                  False                 False  United Kingdom
# 659951                   True                 False  United Kingdom
# 541593                   True                 False           Malta
# 425158                   True                 False     Netherlands
#
#        salary_rate  salary_year_avg  salary_hour_avg            company_name  \
# 502901        None              NaN              NaN           ManpowerGroup
# 406337        None              NaN              NaN                 Harnham
# 659951        None              NaN              NaN             Morgan King
# 541593        None              NaN              NaN                 Konnekt
# 425158        None              NaN              NaN  Independent Recruiters
#
#                                                job_skills  \
# 502901                            ['sql', 'azure', 'git']
# 406337  ['sql', 'python', 'bigquery', 'snowflake', 'lo...
# 659951                                               None
# 541593                                           ['jira']
# 425158                                         ['python']
#
#                                           job_type_skills
# 502901  {'cloud': ['azure'], 'other': ['git'], 'progra...
# 406337  {'analyst_tools': ['looker'], 'cloud': ['bigqu...
# 659951                                               None
# 541593                                {'async': ['jira']}
# 425158                        {'programming': ['python']}

# %%
df['job_title_short'].value_counts()
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
df['job_title_short'] == 'Data Analyst'
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737     True
# 785738    False
# 785739    False
# 785740    False
# Name: job_title_short, Length: 785741, dtype: bool

# %%
sum(df['job_title_short'] == 'Data Analyst')
# Out:
# 196075

# %%
name = 'Ugochukwu'
print(name[::-1])
print(name[:-1:])
print(name[-1::])
# Out:
# uwkuhcogU
# Ugochukw
# u

# %%
print(name[::1])
print(name[:1:])
print(name[1::])
# Out:
# Ugochukwu
# U
# gochukwu
