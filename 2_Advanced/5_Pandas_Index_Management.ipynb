# %%
# Import the libraries

import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

# Load the Dataset from HuggingFace
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_canada_jobs = df[df['job_country'] == 'Canada']

# %%
df_canada_jobs
# Out:
#                   job_title_short  \
# 50      Machine Learning Engineer
# 59                  Data Engineer
# 81                   Data Analyst
# 85      Machine Learning Engineer
# 98           Senior Data Engineer
# ...                           ...
# 785317              Data Engineer
# 785327              Data Engineer
# 785339              Data Engineer
# 785511              Data Engineer
# 785643             Data Scientist
#
#                                                 job_title  \
# 50               Sr ML Engineer - Research & NLP (Remote)
# 59                   Data Engineer with Dremio Experience
# 81                                  Business Data Analyst
# 85      Machine Learning Engineer/Scientist High Perfo...
# 98                             Senior Data Engineer (AWS)
# ...                                                   ...
# 785317                        Data Engineer, Finance Data
# 785327                                Azure Data Engineer
# ...

# %%
df_canada_jobs.reset_index()
# Out:
#         index            job_title_short  \
# 0          50  Machine Learning Engineer
# 1          59              Data Engineer
# 2          81               Data Analyst
# 3          85  Machine Learning Engineer
# 4          98       Senior Data Engineer
# ...       ...                        ...
# 16024  785317              Data Engineer
# 16025  785327              Data Engineer
# 16026  785339              Data Engineer
# 16027  785511              Data Engineer
# 16028  785643             Data Scientist
#
#                                                job_title  \
# 0               Sr ML Engineer - Research & NLP (Remote)
# 1                   Data Engineer with Dremio Experience
# 2                                  Business Data Analyst
# 3      Machine Learning Engineer/Scientist High Perfo...
# 4                             Senior Data Engineer (AWS)
# ...                                                  ...
# 16024                        Data Engineer, Finance Data
# ...

# %%
df_canada_jobs.index.name = 'S/N: Canada Jobs'

# %%
df_canada_jobs.sample(5)
# Out:
#                     job_title_short  \
# S/N: Canada Jobs
# 470864            Software Engineer
# 105885                Data Engineer
# 689159                 Data Analyst
# 154475                 Data Analyst
# 31099                 Data Engineer
#
#                                                           job_title  \
# S/N: Canada Jobs
# 470864                                Technical Performance Analyst
# 105885                                                Data Engineer
# 689159                                                 Data Analyst
# 154475                                                 Data Analyst
# 31099             Consulting Engineer - Data Center Networking (...
#
#                           job_location           job_via job_schedule_type  \
# S/N: Canada Jobs
# 470864                        Anywhere      via LinkedIn        Contractor
# 105885            Oakville, ON, Canada         via BeBee         Full-time
# ...

# %%
df_canada_jobs_copy = df_canada_jobs.copy()

# %%
df_canada_jobs_copy.reset_index(inplace = True)

# %%
df_canada_jobs_copy
# Out:
#        S/N: Canada Jobs            job_title_short  \
# 0                    50  Machine Learning Engineer
# 1                    59              Data Engineer
# 2                    81               Data Analyst
# 3                    85  Machine Learning Engineer
# 4                    98       Senior Data Engineer
# ...                 ...                        ...
# 16024            785317              Data Engineer
# 16025            785327              Data Engineer
# 16026            785339              Data Engineer
# 16027            785511              Data Engineer
# 16028            785643             Data Scientist
#
#                                                job_title  \
# 0               Sr ML Engineer - Research & NLP (Remote)
# 1                   Data Engineer with Dremio Experience
# 2                                  Business Data Analyst
# 3      Machine Learning Engineer/Scientist High Perfo...
# 4                             Senior Data Engineer (AWS)
# ...

# %%
df_canada_jobs
# Out:
#                             job_title_short  \
# S/N: Canada Jobs
# 50                Machine Learning Engineer
# 59                            Data Engineer
# 81                             Data Analyst
# 85                Machine Learning Engineer
# 98                     Senior Data Engineer
# ...                                     ...
# 785317                        Data Engineer
# 785327                        Data Engineer
# 785339                        Data Engineer
# 785511                        Data Engineer
# 785643                       Data Scientist
#
#                                                           job_title  \
# S/N: Canada Jobs
# 50                         Sr ML Engineer - Research & NLP (Remote)
# 59                             Data Engineer with Dremio Experience
# 81                                            Business Data Analyst
# 85                Machine Learning Engineer/Scientist High Perfo...
# ...

# %%
df_canada_jobs_copy.set_index("S/N: Canada Jobs")
# Out:
#                             job_title_short  \
# S/N: Canada Jobs
# 50                Machine Learning Engineer
# 59                            Data Engineer
# 81                             Data Analyst
# 85                Machine Learning Engineer
# 98                     Senior Data Engineer
# ...                                     ...
# 785317                        Data Engineer
# 785327                        Data Engineer
# 785339                        Data Engineer
# 785511                        Data Engineer
# 785643                       Data Scientist
#
#                                                           job_title  \
# S/N: Canada Jobs
# 50                         Sr ML Engineer - Research & NLP (Remote)
# 59                             Data Engineer with Dremio Experience
# 81                                            Business Data Analyst
# 85                Machine Learning Engineer/Scientist High Perfo...
# ...

# %%
median_pivot = df_canada_jobs.pivot_table(values = 'salary_year_avg', index = 'job_title_short', 
                                        aggfunc = ['median', 'min', 'max'])

# %%
median_pivot
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  85000.0         60000.0        190000.0
# Cloud Engineer                   130000.0         90000.0        204000.0
# Data Analyst                      98500.0         49566.5        160000.0
# Data Engineer                    105000.0         60000.0        375000.0
# Data Scientist                   122500.0         63000.0        350000.0
# Machine Learning Engineer        149653.0         63000.0        325000.0
# Senior Data Analyst              111175.0         67500.0        175000.0
# Senior Data Engineer             125000.0         64800.0        200000.0
# Senior Data Scientist            130000.0         54907.0        231000.0
# Software Engineer                125000.0         63000.0        225000.0

# %%
median_pivot.sort_values(by = ('median', 'salary_year_avg'), ascending = False)
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Machine Learning Engineer        149653.0         63000.0        325000.0
# Cloud Engineer                   130000.0         90000.0        204000.0
# Senior Data Scientist            130000.0         54907.0        231000.0
# Senior Data Engineer             125000.0         64800.0        200000.0
# Software Engineer                125000.0         63000.0        225000.0
# Data Scientist                   122500.0         63000.0        350000.0
# Senior Data Analyst              111175.0         67500.0        175000.0
# Data Engineer                    105000.0         60000.0        375000.0
# Data Analyst                      98500.0         49566.5        160000.0
# Business Analyst                  85000.0         60000.0        190000.0

# %%
median_pivot.sort_index()
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  85000.0         60000.0        190000.0
# Cloud Engineer                   130000.0         90000.0        204000.0
# Data Analyst                      98500.0         49566.5        160000.0
# Data Engineer                    105000.0         60000.0        375000.0
# Data Scientist                   122500.0         63000.0        350000.0
# Machine Learning Engineer        149653.0         63000.0        325000.0
# Senior Data Analyst              111175.0         67500.0        175000.0
# Senior Data Engineer             125000.0         64800.0        200000.0
# Senior Data Scientist            130000.0         54907.0        231000.0
# Software Engineer                125000.0         63000.0        225000.0
